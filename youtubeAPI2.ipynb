# %%
# Import Packages

import pandas as pd
import googleapiclient.discovery

# %%
# YouTube API Access

api_service_name = "youtube"
api_version = "v3"
DEVELOPER_KEY = "AIzaSyB_Bq9ZA4VEk4PhLmgPQO00j-Hz1-nqzXc"

youtube = googleapiclient.discovery.build(
        api_service_name, api_version, developerKey = DEVELOPER_KEY)

# %%
# Function to get video ids from a given playlist

def youtube_videoid(playlist):
    videolist=[]
    request = youtube.playlistItems().list(
        part="contentDetails",
        playlistId=playlistid,maxResults=50
    )
    response = request.execute()
    
    for i in range(len(response['items'])):
                  
        videolist.append(response['items'][i]['contentDetails']['videoId'])
        
    nextpagetoken=response.get('nextPageToken') 
    extra_pages_is_there=True
    
    while extra_pages_is_there:
        if nextpagetoken is None:
            extra_pages_is_there=False
            
        else:
            request = youtube.playlistItems().list(
            part="contentDetails",
            playlistId=playlistid,maxResults=50,pageToken=nextpagetoken
    )
            response = request.execute()
            
            for i in  range(len(response['items'])):
                
                videolist.append(response['items'][i]['contentDetails']['videoId'])
                
            nextpagetoken=response.get('nextPageToken')    
        
            
      
        
            
            
    return videolist

# %%
type(response['items'][0]['contentDetails']['videoId'])
# Out:
# str

# %%
len(response['items'])
# Out:
# 18

# %%
playlistid='PL2fxME0rbf-3UJJT3uux7BaNEgBV0MRvp'

# %%
# Finding length of function output

len(youtube_videoid(playlistid))
# Out:
# 168

# %%
# Running function for given playlist id
youtube_videoid(playlistid)

# %%
videoinfo=youtube_videoid(playlistid)

# %%
videoinfo
# Out:
# ['87Qczya5HTU',
#  'FEAHnilxy6w',
#  'hLqGReZSr5c',
#  '_DYuHz9VBLo',
#  'HSUsSBk7Wqg',
#  'Q1ZJ3NaVYNA',
#  '4TbdqWbF_PE',
#  'cGNTVozi6Ns',
#  'U5CYdmsR9Sw',
#  '9vyKAKUX0WI',
#  'HixoHQPLFSs',
#  'WNCOSPaOst8',
#  'Pylw3tqzv1U',
#  'ie-n7tIX0EU',
#  '0Ef0Iy9Vf_A',
#  '1ktVglH2xk4',
#  'DvjCPu0odG4',
#  '-xOZP3Ut8J0',
#  'g6UHikNtmy4',
#  'b46D9QnK4jA',
#  'djM5ungZ6mo',
#  'q-cuNO4UanY',
#  '98YROwxUI4Y',
#  'o-OhcV9H6pw',
#  'iWBjHPFrwrM',
#  'NPLa-JDGjcg',
#  '7L-xmfgKomA',
#  'zhzv4eQ97mU',
#  'UHkN7ZrvcNQ',
#  'ctYaB_e4Lb0',
#  'gWs8iAgB6Ek',
#  'IsuZEoMGCsA',
#  'qgFaOB-pNMU',
#  'iptbESNg_mc',
#  '4FXf_bV95yU',
#  'irtdoP3YqCk',
#  'UP-n1nt_jo8',
#  'QKng1gSDq80',
#  'Ep08ccGf0mM',
#  'CW-iEVN8zyk',
#  '-fktVCXDDac',
#  'upet0P9p3xU',
#  'yPtUDNUO7BQ',
#  'p2g8xXjsXyg',
#  '0QtG_bRhGM0',
#  'gTWWJ00Btg4',
#  'AeJO5BV-mWo',
#  'hjglquW-RRA',
#  'Gcox6BZXGxU',
#  '1SyX64uQTgM',
#  'xhFfRLTb45w',
#  'bUXLJiZhb8M',
#  'qTlmXPUOG_k',
#  '9RNoid4y7i4',
#  '_fwHMckVLa8',
#  'iJwbHeQkfDc',
#  'D3AAiauEbsg',
#  'pAgaEWah0kg',
#  '30wmprUlw3I',
#  'LIWTSmk1rlI',
#  'zDj4VoNu0yg',
#  'rRLgWn8sfxw',
#  'uwYJeiECR9E',
#  '93RGd512qrw',
#  'bZPDW062vgU',
#  'g0hFUTMrw2c',
#  'kczsCOd8iKA',
#  'SuU1eAQd900',
#  'aSxNaJvAgl4',
#  '6FVI-0a5YXg',
#  'jj5KiWvIFes',
#  'vnq8i-Rdw08',
#  'P94DxjckQh8',
#  'KooB6MqY-jw',
#  'eNyNtj2zf3A',
#  'hjcvBHuPKrA',
#  'wEXtbPxbDlc',
#  'mBun0K5exVM',
#  'yq5VEdfTZIc',
#  '8Q1OXvjS4yM',
#  'Gz07wOEk8YQ',
#  'sjRjE0lxKQQ',
#  'OY4otpxkeqs',
#  '1I-XQViRFq0',
#  'ZWz7eqbsJmk',
#  'nnK8kbibtgs',
#  'YWA214UdNjk',
#  's9oSsNGC3H0',
#  'hOrqOJ6dXO8',
#  '8fUcU4nkKgs',
#  'X5NBRp9tWO4',
#  'E8hjR3F3QOs',
#  'sp_EtDL5XoI',
#  'EKzofU_8FnU',
#  'NjKTvIMWqxM',
#  'V2ailBMoBoI',
#  '2r2eDY2qTsg',
#  'zwLHJlNMlf4',
#  'SqNehYabteo',
#  'I3O-viCUS3A',
#  'lAfd44X_ZS8',
#  'Mmv7Pt91tO4',
#  '9Tc8-LiAcDU',
#  'jtvysmkz-qM',
#  '2Ms2gG27wyA',
#  'e2JUsVCxqTk',
#  'Oj8QpbNdfwE',
#  'ECc_0RCyYY0',
#  'gAfWIPnbjq0',
#  'reV-oxdm_bU',
#  'OlRXgBRvO7g',
#  'h10GygeLL8I',
#  '-pXIGwbnRwc',
#  'dE2cjK8chQ8',
#  'Rt21-qOqNKg',
#  'wggDXnby1UU',
#  'B348n650iLM',
#  'ViPPMraSTeo',
#  'Rxu-WSCVEi0',
#  'HpkOye6CBp0',
#  'ezzsId2DaUs',
#  'lmbaOrsoPGM',
#  'D7BUvtIWi2s',
#  'Q8zPmD2sU9U',
#  'kg2P_Rpns3Y',
#  'Y5PDep8SmSA',
#  'MRYw1hwWa4s',
#  'LYNKvboBRqQ',
#  'IGLkUuY2SJ0',
#  'u70OpBPtlZo',
#  'HuvpsT--KVE',
#  'm81ihLG1ZWg',
#  'eI8hZWbGCoU',
#  'IEeJGw4yCN8',
#  'WfSE9t1PRtM',
#  'dpNfQ84JTIU',
#  '2WNJO0ybd4g',
#  'sdrZoDy-o-Q',
#  '96KM562jyKI',
#  'aYzxX-T1CUs',
#  'YBDmDCruHmA',
#  '-dNfBZmPly0',
#  'YnhJDPk9SUs',
#  'MOxRi965ybM',
#  'PUBebNPSjm4',
#  'BNCZOFy1neE',
#  'Wr35FD-Qgj0',
#  'kvBZjKXVyP8',
#  'jbNi7aXEcJk',
#  '5jX7Fvwhm3c',
#  'u2y4QhvLWbQ',
#  'q4tO3T5krrM',
#  'Jo8aE5HUeIM',
#  'tLNEIjPfR1U',
#  'HsXy7QSqVLU',
#  '7eKnAd7FYy8',
#  'Xt-jFF6dlgk',
#  '6EhwY1xf6fw',
#  'g5pV1X0Ej08',
#  'eV_N9cuW-j4',
#  'SaNCeXsOGEg',
#  'i-zP6Pz81x8',
#  'RMMSiS_ltZc',
#  '4Dg9h7_yjww',
#  'VX4FC7w6S1g',
#  'S-ftZp4xTnk',
#  '8aUE171gzIA',
#  'O5v-4Lj43mg']

# %%
# Function to get video details using video ids

def videodetails(videoinfo):
    videodetails=[]
    for i in range(0,len(videoinfo),50):
        request = youtube.videos().list(
        part="snippet,statistics",
        id=','.join(videoinfo[i:i+50])
    )
        response = request.execute() 
        
        for i in range(len(response['items'])):
            videodata=dict(title_name=response['items'][i]['snippet']['title'],
                          publishing_date=response['items'][i]['snippet']['publishedAt'],
                          views=response['items'][i]['statistics']['viewCount'],
                          comments=response['items'][i]['statistics']['commentCount'],
                          likes=response['items'][i]['statistics']['likeCount'])
            
            videodetails.append(videodata)
            
        
        

        
    


    return videodetails

# %%
# Running function for given video ids

finaldata=videodetails(videoinfo)

# %%
# Dataframe of video details

finalinfo=pd.DataFrame(finaldata)

# %%
# Video details Information

finalinfo.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 168 entries, 0 to 167
# Data columns (total 7 columns):
#  #   Column           Non-Null Count  Dtype
# ---  ------           --------------  -----
#  0   title_name       168 non-null    object
#  1   publishing_date  168 non-null    datetime64[ns, UTC]
#  2   views            168 non-null    int64
#  3   comments         168 non-null    int64
#  4   likes            168 non-null    int64
#  5   month            168 non-null    int64
#  6   year             168 non-null    int64
# dtypes: datetime64[ns, UTC](1), int64(5), object(1)
# memory usage: 9.3+ KB

# %%
# Converting columns to integer datatype
finalinfo['views']=pd.to_numeric(finalinfo['views'])
finalinfo['comments']=pd.to_numeric(finalinfo['comments'])
finalinfo['likes']=pd.to_numeric(finalinfo['likes'])

# %%
# Converting date to datetime from object

finalinfo['publishing_date']=pd.to_datetime(finalinfo['publishing_date'])

# %%
# Creating new columns for month,year

finalinfo['month']=finalinfo['publishing_date'].dt.month
finalinfo['year']=finalinfo['publishing_date'].dt.year

# %%
# Creating new columns for yearmonth

finalinfo['yearmonth']=finalinfo['month'].astype(str)+"-"+finalinfo['year'].astype(str)

# %%
# Sorting top 10 videos by views
finalinfo.sort_values(by='views',ascending=False).head(10)
# Out:
#                                             title_name  \
# 18   Fundamental Analysis of 3 Small Cap and Penny ...
# 64        How to make regular income from investments?
# 131  How to make dividend income | 5 great assets t...
# 3    Become a MILLIONAIRE by 30! - Investment Strat...
# 4    INR 1 Cr. in Stock Market | Learn Fundamental ...
# 9    How to invest your first INR 1 lakh? | Stock M...
# 29            5 GREAT stocks for long term! #Smallcase
# 89   1 stock, 100% gains | Multibagger stock findin...
# 39   Where to invest? | Best Mutual Funds (2021 & 2...
# 59              Inexpensive stocks: Are they worth it?
#
#               publishing_date    views  comments  likes  month  year yearmonth
# 18  2021-08-05 15:38:40+00:00  1670847      2863  43866      8  2021    8-2021
# 64  2021-11-26 15:00:14+00:00   913967      3341  25186     11  2021   11-2021
# 131 2022-03-22 15:09:36+00:00   772397      2637  23180      3  2022    3-2022
# 3   2021-06-19 14:50:51+00:00   656353      2706  42775      6  2021    6-2021
# 4   2021-06-12 14:37:55+00:00   585011      1979  31961      6  2021    6-2021
# 9   2021-07-03 15:08:28+00:00   538378      2249  22483      7  2021    7-2021
# 29  2021-08-31 15:00:32+00:00   535153      1328  17632      8  2021    8-2021
# 89  2022-01-07 15:00:36+00:00   534850      1651  30161      1  2022    1-2022
# 39  2021-09-30 15:00:17+00:00   531197      2041  20068      9  2021    9-2021
# 59  2021-11-12 15:00:47+00:00   528003      1078  12909     11  2021   11-2021
